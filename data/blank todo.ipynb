# %%
from urllib.request import urlopen
from PyPDF2 import PdfReader
import requests
import io
import pandas as pd
from bs4 import BeautifulSoup
import re
import csv
import re
import csv
import shootings_processor

# %%
shootings_processor.shooting_pdfurls()
# Out:
# /Users/yiv/Documents/CRP-ra/data/shootings_processor.py:30: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 30 of the file /Users/yiv/Documents/CRP-ra/data/shootings_processor.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   soup = BeautifulSoup(req.content,"html")
# ['https://da.lacounty.gov/sites/default/files/pdf/JSID-OIS-04-15-2020-Jaradat.pdf',
#  'https://da.lacounty.gov/sites/default/files/pdf/JSID-OIS-11-08-22-Gresham_0.pdf',
#  'https://da.lacounty.gov/sites/default/files/pdf/JSID-OIS-09-14-22-Briggs-Jr_1.pdf',
#  'https://da.lacounty.gov/sites/default/files/pdf/JSID-OIS-11-01-23-Castellanos.pdf',
# ...

# %%
# get new urls by comparing to database

# import shooting_process, try to do it

# if good, then display the rows and ask to confirm db input

# if can't, raise an exception and prompt manual entry

# %%
input()
# Out:
# 3
# '3'
